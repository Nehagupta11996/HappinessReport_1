# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing the libraries

# %%
df=pd.read_csv("happiness_score_dataset.csv")

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# IMPORTED THE DATASET

# %% [markdown]
# DOING THE EDA (EXPLORATORY DATA ANALYSIS) ON THE DATASET TO UNDERSTAND THE DATA

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# THERE ARE 158 ROWS AND 12 COLUMNS

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df["Happiness Rank"].unique
# Out:
# <bound method Series.unique of 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 153    154
# 154    155
# 155    156
# 156    157
# 157    158
# Name: Happiness Rank, Length: 158, dtype: int64>

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# COLUMNS NAME

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# COLUMNS INFORMATION ABOUT THEIR DATA TYPE

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# The standard deviation of happiness rank is too high means data is more deviated.
# There is no much skweness in the data as the difference between the mean and median is less
# There are extreme outliers in Happiness Rank columns as there is difference between 75% and max

# %%
df["Happiness Score"].unique
# Out:
# <bound method Series.unique of 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64>

# %% [markdown]
# Alomost all the values are unique

# %%
df["Happiness Score"].value_counts()
# Out:
# 5.192    2
# 4.642    1
# 5.098    1
# 5.129    1
# 5.889    1
#         ..
# 4.252    1
# 4.633    1
# 3.931    1
# 7.200    1
# 6.750    1
# Name: Happiness Score, Length: 157, dtype: int64

# %%
df["Region"].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# There is no null values in the dataset

# %%
dfcor=df.corr()
dfcor
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %% [markdown]
# corelation of the data

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Happiness rank column is negatively correlated with happiness score

# %%
plt.figure(figsize=(6,4))
sns.heatmap(dfcor,cmap="Blues",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# CORRELATION OF THE DATASET WITH VALUES

# %% [markdown]
# PLOTTING THE OUTLIERS

# %%
collist=df.columns.values
ncol=12
nrows=10

# %% [markdown]
# To plot the data should be in numeric form so changing the data in to numeric form

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["Region"]=LE.fit_transform(df["Region"])

# %% [markdown]
# Apllied label encoder on the region column to convert it into int

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    int32
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.drop("Country",axis=1,inplace=True)

# %% [markdown]
# dropped the country column because all the values were unique

# %%
df["Region"] = df['Region'].astype(float)

# %% [markdown]
# converted the region column to float

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Region                         158 non-null    float64
#  1   Happiness Rank                 158 non-null    int64
#  2   Happiness Score                158 non-null    float64
#  3   Standard Error                 158 non-null    float64
#  4   Economy (GDP per Capita)       158 non-null    float64
#  5   Family                         158 non-null    float64
#  6   Health (Life Expectancy)       158 non-null    float64
#  7   Freedom                        158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Generosity                     158 non-null    float64
#  10  Dystopia Residual              158 non-null    float64
# dtypes: float64(10), int64(1)
# memory usage: 13.7 KB

# %%
collist=df.columns.values
ncol=12
nrows=11


plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color="green",orient="v")
    plt.tight_layout()

# %% [markdown]
# There are total 5 columns were there are outliers

# %%
df.head()
# Out:
#    Region  Happiness Rank  Happiness Score  Standard Error  \
# 0     9.0               1            7.587         0.03411
# 1     9.0               2            7.561         0.04884
# 2     9.0               3            7.527         0.03328
# 3     9.0               4            7.522         0.03880
# 4     5.0               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# ...

# %%
sns.displot(df["Standard Error"])

# %%
sns.displot(df["Family"])

# %%
sns.displot(df["Trust (Government Corruption)"])

# %%
sns.displot(df["Generosity"])

# %%
sns.displot(df["Dystopia Residual"])

# %% [markdown]
# In above plotted graphs skewness is present because there are outliers

# %%
plt.figure(figsize=(16,16))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.displot(df[collist[i]])

# %%
sns.pairplot(df)

# %% [markdown]
# # DATA CLEANING PROCESS

# %%
df.drop("Happiness Rank",axis=1,inplace=True)

# %% [markdown]
# Dropped happiness rank column because the values of happiness column are negatively correated with the happiness score

# %%
df.shape
# Out:
# (158, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Region                         158 non-null    float64
#  1   Happiness Score                158 non-null    float64
#  2   Standard Error                 158 non-null    float64
#  3   Economy (GDP per Capita)       158 non-null    float64
#  4   Family                         158 non-null    float64
#  5   Health (Life Expectancy)       158 non-null    float64
#  6   Freedom                        158 non-null    float64
#  7   Trust (Government Corruption)  158 non-null    float64
#  8   Generosity                     158 non-null    float64
#  9   Dystopia Residual              158 non-null    float64
# dtypes: float64(10)
# memory usage: 12.5 KB

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.30025593, 1.93736005, 0.80592569, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [1.30025593, 1.91458063, 0.05588945, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [1.30025593, 1.88479215, 0.8544869 , ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [0.37544095, 2.0761992 , 0.13253425, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [0.96511655, 2.1646885 , 2.26396166, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [0.96511655, 2.22251319, 1.13418227, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#      Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0       9.0            7.587         0.03411                   1.39651
# 1       9.0            7.561         0.04884                   1.30232
# 2       9.0            7.527         0.03328                   1.32548
# 3       9.0            7.522         0.03880                   1.45900
# 4       5.0            7.427         0.03553                   1.32629
# ..      ...              ...             ...                       ...
# 150     8.0            3.655         0.05141                   0.46534
# 151     8.0            3.587         0.04324                   0.25812
# 152     7.0            3.575         0.03084                   0.31982
# 154     8.0            3.340         0.03656                   0.28665
# 156     8.0            2.905         0.08658                   0.01530
#
#       Family  Health (Life Expectancy)  Freedom  \
# 0    1.34951                   0.94143  0.66557
# ...

# %% [markdown]
# removed the outliers

# %%
df_new.shape
# Out:
# (149, 10)

# %%
df.shape
# Out:
# (158, 10)

# %% [markdown]
# Data is ready

# %%
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# imported the libraries required for machine learning of the data

# %% [markdown]
# As this is linear regression problem imported the linear regression libraries

# %%
df_new.keys()
# Out:
# Index(['Region', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df_new=df_new.reindex(columns=["Region","Standard Error","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption)","Generosity","Dystopia Residual","Happiness Score"])

# %%
df_new.keys()
# Out:
# Index(['Region', 'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Happiness Score'],
#       dtype='object')

# %%
x=df_new.iloc[:,0:-1]
x.head()
# Out:
#    Region  Standard Error  Economy (GDP per Capita)   Family  \
# 0     9.0         0.03411                   1.39651  1.34951
# 1     9.0         0.04884                   1.30232  1.40223
# 2     9.0         0.03328                   1.32548  1.36058
# 3     9.0         0.03880                   1.45900  1.33095
# 4     5.0         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# ...

# %%
y=df_new.iloc[:,-1]
y.head()
# Out:
# 0    7.587
# 1    7.561
# 2    7.527
# 3    7.522
# 4    7.427
# Name: Happiness Score, dtype: float64

# %% [markdown]
# separated the x and y data

# %%
x.shape
# Out:
# (149, 9)

# %%
y.shape
# Out:
# (149,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=42)

# %%
x_train.shape
# Out:
# (104, 9)

# %%
y_train.shape
# Out:
# (104,)

# %%
x_test.shape
# Out:
# (45, 9)

# %%
y_test.shape
# Out:
# (45,)

# %%
lm=LinearRegression()

# %% [markdown]
# Making the instance of the class

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# training data

# %%
lm.coef_
# Out:
# array([-1.10581657e-05, -6.35083235e-04,  1.00014646e+00,  9.99900566e-01,
#         9.99696453e-01,  9.99769134e-01,  1.00007798e+00,  1.00000486e+00,
#         9.99964999e-01])

# %%
lm.intercept_
# Out:
# 0.00040002291628482567

# %%
df_new.columns
# Out:
# Index(['Region', 'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Happiness Score'],
#       dtype='object')

# %%
lm.score(x_train,y_train)
# Out:
# 0.999999936494082

# %%
#predict the value
pred=lm.predict(x_test)
print("predicted result price:",pred)
print("actual price",y_test)
# Out:
# predicted result price: [5.28634835 6.93725838 4.51227859 5.19231499 5.21202728 6.47671775
#  5.60462915 3.7808274  5.47389638 5.12420096 4.64233607 7.19971664
#  6.29813422 7.28401668 6.90136815 5.81255231 3.9037868  5.42862829
#  5.82408962 4.03307008 6.50504058 4.3322062  6.66961585 4.25203782
#  4.21856303 3.65518144 4.6334679  4.78794157 5.97520891 6.48510662
#  6.81014322 6.98251753 5.58862323 7.22561629 5.99507884 4.69397428
#  5.85524952 6.57496522 7.42684598 6.45459833 4.41928624 5.09762424
#  5.07330132 6.94616683 7.27758877]
# actual price 76     5.286
# 18     6.937
# 121    4.512
# 81     5.192
# 79     5.212
# 32     6.477
# 67     5.605
# 145    3.781
# 71     5.474
# 85     5.124
# 112    4.642
# 12     7.200
# 37     6.298
# 9      7.284
# 19     6.901
# 58     5.813
# 141    3.904
# 72     5.429
# 57     5.824
# 136    4.033
# 30     6.505
# 127    4.332
# 26     6.670
# 132    4.252
# 133    4.218
# 150    3.655
# 113    4.633
# 104    4.788
# 47     5.975
# ...

# %%
print("error:")
print("mean absolute error:", mean_absolute_error(y_test,pred))
print("mean squared error:", mean_squared_error(y_test,pred))

print("root Mean Squared error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error:
# mean absolute error: 0.00024035122116149074
# mean squared error: 7.860055280622799e-08
# root Mean Squared error: 0.00028035790127304774

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# 0.9999999341450841

# %% [markdown]
# changes in y whenever x is being changed

# %%
df_new=pd.DataFrame(pred)
df.to_csv("Happiness_Submission.csv")

# %%
import joblib
joblib.dump(df_new,"HappinessSubmission1.pkl")
# Out:
# ['HappinessSubmission1.pkl']
